# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from typing import List

class Solution:
  def validMountainArray(self , arr : List[int]) -> bool:
    n = len(arr)
    if n < 3:
      return False

    i = 0
    while i + 1 < n and arr[i] < arr[i + 1]:
      i = i + 1

    if i == 0 or i == n - 1:
      return False

    while i + 1 < n and arr[i] > arr[i + 1]:
      i = i + 1

    return i == n - 1

s = Solution()
print(s.validMountainArray(arr = [1 , 2 , 4 , 5 , 6 , 10 , 9 , 7 , 5 , 3]))
# Out:
# True

# %%
print(s.validMountainArray(arr = [1 , 2 , 4 , 5 , 6 , 10 , 9 , 11 , 5 , 3]))
# Out:
# False
